# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd

# %%
url = 'https://mediakit.iportal.ru/our-team'
header = {
  'accept':'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3',
  'accept-encoding':'gzip, deflate, br',
  'accept-language':'ru-RU,ru;q=0.9,en-US;q=0.8,en;q=0.7',
  'cache-control':'no-cache',
  'dnt': '1',
  'pragma': 'no-cache',
  'sec-fetch-mode': 'navigate',
  'sec-fetch-site': 'none',
  'sec-fetch-user': '?1',
  'upgrade-insecure-requests': '1',
  'user-agent': 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/76.0.3809.100 Safari/537.36'}

session = requests.Session()
session.headers = header
r = session.get(url)

# %%
print(r)
# Out:
# <Response [200]>

# %%
soup = bs(r.text, 'lxml')

# %%
soup.find('div', class_='r t-rec t-rec_pb_60').find('div', class_='t544__descr t-descr t-descr_xs').text
# Out:
# 'Редакционный директор'

# %%
soup.find('div', class_='t396__elem tn-elem tn-elem__3995684841599793822858').find('div', class_='tn-atom').text
# Out:
# 'Андрей Затирко'

# %%
soup.find('div', class_='tn-atom').text
# Out:
# 'Городские порталы Shkulev Media Holding —крупнейшая в России сеть городских онлайн-медиа'

# %%
names = soup.findAll('div', class_='r t-rec t-rec_pb_60')
len(names)
# Out:
# 23

# %%
data = []
for name in names:
    n = name.find('div', class_='tn-atom')
    data.append([n])

# %%
data
# Out:
# [[None],
#  [<div class="tn-atom" field="tn_text_1596441248760">Москва</div>],
#  [<div class="tn-atom"> <img class="tn-atom__img t-img" data-original="https://static.tildacdn.com/tild6664-3364-4162-a639-323932313361/photo.png" imgfield="tn_img_1596441243259"/> </div>],
#  [<div class="tn-atom"> <img class="tn-atom__img t-img" data-original="https://static.tildacdn.com/tild3366-6137-4139-b236-653331646236/photo.jpg" imgfield="tn_img_1596441243259"/> </div>],
#  [<div class="tn-atom"> <img class="tn-atom__img t-img" data-original="https://static.tildacdn.com/tild3264-3164-4533-b733-366338626463/photo.jpg" imgfield="tn_img_1596441243259"/> </div>],
#  [<div class="tn-atom"> <img class="tn-atom__img t-img" data-original="https://static.tildacdn.com/tild3430-3433-4861-a361-343034303761/photo_3.jpg" imgfield="tn_img_1596441243259"/> </div>],
# ...

# %%
data1 = soup.find_all('div', class_='r t-rec t-rec_pb_60')

# %%
for i in data1:
    good = i.text
    print(good)
# Out:
# Ольга ПрохороваРедакционный директор8 800 2000-383o.prokhorova@iportal.ru
#
#
#
# Москва
#
#
#
#
#
#
# Андрей Затирко
#
# Главный редактор
#
# Национальная редакция
#
#
#
#
# Ольга Беляева
#
# Руководительrednews@iportal.ru
#
# Оксана Маклакова
#
# Главный редакторmsk1@iportal.ru
#
#
#
#
#
# Екатеринбург
#
# Артем Беседин
#
#
#
#
# Главный редакторe1@iportal.ru
#
# Новосибирск
#
#
#
#
# ИО главного редактораngs@iportal.ru
#
#
#
# Елена Гурьянова
#
#
#
#
#
# Нижний Новгород
#
# Денис Стрелков
#
#
#
#
# Главный редакторnn@iportal.ru
#
#
#
# Челябинск
#
# Мария Филипцева
#
#
#
#
# Главный редактор74@iportal.ru
#
#
#
#
#
#
#
# Кемерово
#
# Анастасия Ильина
#
#
#
#
# Главный редакторngs24@iportal.ru
#
#
#
# Тюмень
#
# Александра Марчук
#
#
#
#
# Редакционный директор 72@iportal.ru
#
#
#
#
#
# Пермь
#
# Екатерина Вохмянина
#
#
#
#
# Главный редактор59@iportal.ru
#
#
#
# Волгоград
#
# Николай Смуров
#
#
#
#
# Главный редакторv1@iportal.ru
#
#
#
#
#
# Ростов-на-Дону
#
# Валентин Булавко
#
#
# ...
